# %%
import tweepy

import pandas as pd

# %%
CONSUMER_KEY = '' # INSERT API/CONSUMER KEY
CONSUMER_SECRET = '' # INSERT API/CONSUMER SECRET
ACCESS_TOKEN = '' # INSERT ACCESS TOKEN
ACCESS_TOKEN_SECRET = '' # INSERT ACCESS SECRET

# %%
# PASS IN YOUR AUTHENTICATION DETAILS

auth = tweepy.OAuth1UserHandler(CONSUMER_KEY,
                                CONSUMER_SECRET,
                                ACCESS_TOKEN,
                                ACCESS_TOKEN_SECRET)

# %%
# INSTANTIATE

api = tweepy.API(auth)

# %%
# GET TWEETS FROM MY TIMELINE

home_tweets = api.home_timeline(tweet_mode = "extended")

# %%
home_tweets[4].full_text
# Out:
# 'Ayra Starr “Sability” Official Video surpasses 14 Million Streams on YouTube https://t.co/DoziqcvPeg'

# %%
home_tweets[1]._json
# Out:
# {'created_at': 'Mon Apr 10 10:04:06 +0000 2023',
#  'id': 1645367041573138432,
#  'id_str': '1645367041573138432',
#  'full_text': 'Jabeur wins Charleston Open for her first title of season https://t.co/nDZYoRzmsh',
#  'truncated': False,
#  'display_text_range': [0, 81],
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [{'url': 'https://t.co/nDZYoRzmsh',
#     'expanded_url': 'http://dlvr.it/SmFfrB',
#     'display_url': 'dlvr.it/SmFfrB',
#     'indices': [58, 81]}]},
#  'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 4248352301,
#   'id_str': '4248352301',
#   'name': 'The Paradise',
#   'screen_name': 'TheParadiseNg',
#   'location': 'Woldwide',
#   'description': 'Breaking News and Top Stories across the world.',
#   'url': 'https://t.co/fpmBPhFTaq',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/fpmBPhFTaq',
#       'expanded_url': 'https://theparadise.ng',
#       'display_url': 'theparadise.ng',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 15830,
#   'friends_count': 10180,
#   'listed_count': 9,
#   'created_at': 'Sun Nov 22 08:40:04 +0000 2015',
#   'favourites_count': 20873,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 74316,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1572640936676450305/X7WOiLPk_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1572640936676450305/X7WOiLPk_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4248352301/1663781791',
#   'profile_link_color': '03368C',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': True,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'possibly_sensitive_appealable': False,
#  'lang': 'en'}

# %%
home_tweets[5]._json
# Out:
# {'created_at': 'Mon Apr 10 10:03:17 +0000 2023',
#  'id': 1645366836584759296,
#  'id_str': '1645366836584759296',
#  'full_text': 'RT @AnshelPfeffer: Likud plummeting in the polls. 3rd after Gantz and Lapid’s centrist parties. Down from 32 Knesset seats just 4 months ag…',
#  'truncated': False,
#  'display_text_range': [0, 140],
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'AnshelPfeffer',
#     'name': 'Anshel Pfeffer אנשיל פפר',
#     'id': 793879086,
#     'id_str': '793879086',
#     'indices': [3, 17]}],
#   'urls': []},
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 24506246,
#   'id_str': '24506246',
#   'name': 'Haaretz.com',
#   'screen_name': 'haaretzcom',
#   'location': 'Israel',
#   'description': 'All the news, opinion and analysis from Israel, the Middle East and the Jewish World',
#   'url': 'https://t.co/tKQraKpunN',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/tKQraKpunN',
#       'expanded_url': 'http://www.haaretz.com',
#       'display_url': 'haaretz.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 411246,
#   'friends_count': 1915,
#   'listed_count': 9989,
#   'created_at': 'Sun Mar 15 09:43:07 +0000 2009',
#   'favourites_count': 665,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 443921,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '131516',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1537368655285075969/Mpd5uFRm_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1537368655285075969/Mpd5uFRm_normal.png',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/24506246/1541960886',
#   'profile_link_color': '046380',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': '95E8EC',
#   'profile_text_color': '3C3940',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': True,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Sun Apr 09 17:39:00 +0000 2023',
#   'id': 1645119133036544002,
#   'id_str': '1645119133036544002',
#   'full_text': 'Likud plummeting in the polls. 3rd after Gantz and Lapid’s centrist parties. Down from 32 Knesset seats just 4 months ago to only 20 now. https://t.co/3x9uIwlk69',
#   'truncated': False,
#   'display_text_range': [0, 137],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 1645119113931509760,
#      'id_str': '1645119113931509760',
#      'indices': [138, 161],
#      'media_url': 'http://pbs.twimg.com/media/FtSjHi8X0AANO0M.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/FtSjHi8X0AANO0M.jpg',
#      'url': 'https://t.co/3x9uIwlk69',
#      'display_url': 'pic.twitter.com/3x9uIwlk69',
#      'expanded_url': 'https://twitter.com/AnshelPfeffer/status/1645119133036544002/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 579, 'h': 543, 'resize': 'fit'},
#       'large': {'w': 579, 'h': 543, 'resize': 'fit'},
#       'small': {'w': 579, 'h': 543, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1645119113931509760,
#      'id_str': '1645119113931509760',
#      'indices': [138, 161],
#      'media_url': 'http://pbs.twimg.com/media/FtSjHi8X0AANO0M.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/FtSjHi8X0AANO0M.jpg',
#      'url': 'https://t.co/3x9uIwlk69',
#      'display_url': 'pic.twitter.com/3x9uIwlk69',
#      'expanded_url': 'https://twitter.com/AnshelPfeffer/status/1645119133036544002/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 579, 'h': 543, 'resize': 'fit'},
#       'large': {'w': 579, 'h': 543, 'resize': 'fit'},
#       'small': {'w': 579, 'h': 543, 'resize': 'fit'}}}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 793879086,
#    'id_str': '793879086',
#    'name': 'Anshel Pfeffer אנשיל פפר',
#    'screen_name': 'AnshelPfeffer',
#    'location': 'Jerusalem',
#    'description': 'Mancunian hack @haaretz writer @TheEconomist correspondent, unauthorized biographer of Netanyahu and Ovadya Yosef. Next book: God Fearers @penguinpress 👇 Nonno',
#    'url': 'https://t.co/XDGsp5knMD',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/XDGsp5knMD',
#        'expanded_url': 'http://www.haaretz.com',
#        'display_url': 'haaretz.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 55630,
#    'friends_count': 2573,
#    'listed_count': 1275,
#    'created_at': 'Fri Aug 31 13:35:40 +0000 2012',
#    'favourites_count': 38273,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 45005,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1193883252127338496/Pg7TnXJt_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1193883252127338496/Pg7TnXJt_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/793879086/1674309200',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 346,
#   'favorite_count': 2156,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  'is_quote_status': False,
#  'retweet_count': 346,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %%
# home_tweets[2].retweeted_status.full_text

# %%
# status =

# %%
# for tweet in home_tweets:
#     if 'RT' in tweet.text:
#         print(str(tweet.id) + '\t' + tweet.entities['user_mentions'][0]['screen_name'] + '\t' +
#               tweet.entities['user_mentions'][0]['name'] + '\t\t' + tweet.text + '\n')

# %%
tweet_id = []
created_at = []
user_name = []
name = []
tweet_text = []
retweeted_by = []
hashtags = []

# %%
for tweet in home_tweets:
    if 'RT' in tweet.full_text:
        tweet_id.append(tweet.retweeted_status.id)

        created_at.append(str(tweet.retweeted_status.created_at.year) + '-' + 
                          str(tweet.retweeted_status.created_at.month) + '-' + 
                          str(tweet.retweeted_status.created_at.day))

        user_name.append(tweet.retweeted_status.user.screen_name)

        name.append(tweet.retweeted_status.user.name)

        tweet_text.append(tweet.retweeted_status.full_text)

        retweeted_by.append(tweet.user.screen_name)

        if len(tweet.entities['hashtags']) > 0:
            for hashtag in tweet.entities['hashtags']:
                hashtags.append(hashtag)
        else:
            hashtags.append('#')
    else:
        tweet_id.append(tweet.id)
        
        created_at.append(str(tweet.created_at.year) + '-' + 
                          str(tweet.created_at.month) + '-' + 
                          str(tweet.created_at.day))
        
        user_name.append(tweet.user.screen_name)
        
        name.append(tweet.user.name)
        
        tweet_text.append(tweet.full_text)
        
        retweeted_by.append('')
        
        if len(tweet.entities['hashtags']) > 0:
            for hashtag in tweet.entities['hashtags']:
                hashtags.append(hashtag)
        else:
            hashtags.append('#')

# %%
tweets_scrape_to_dict = {'Tweet_ID': tweet_id,
                        'User_Name': user_name,
                        'Name': name,
                        'Tweet_Text': tweet_text,
                        'Retweeted_By': retweeted_by,
                        'Hashtags': hashtags
                       }

# %%
tweets_scrape_df = pd.DataFrame(tweets_scrape_to_dict)

# %%
tweets_scrape_df
# Out:
#                Tweet_ID       User_Name  \
# 0   1645306484375318530       jagganiyu
